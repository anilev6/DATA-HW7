# %%
# Importing necessary libraries
from surprise import SVD, SVDpp, NMF
from surprise import Dataset
from surprise.model_selection import GridSearchCV
from surprise.model_selection import cross_validate

from pandas import DataFrame

# %% [markdown]
# ### Знайдемо найкращі параметри для SVD

# %% [markdown]
# Завантажемо дані.

# %%
# Load the movielens dataset
data = Dataset.load_builtin("ml-100k")

# What's inside?
data_df = DataFrame(data.raw_ratings, columns=["user", "item", "rate", "time"])
print(data_df.head())
# Out:
#   user item  rate       time
# 0  196  242   3.0  881250949
# 1  186  302   3.0  891717742
# 2   22  377   1.0  878887116
# 3  244   51   2.0  880606923
# 4  166  346   1.0  886397596

# %% [markdown]
# **Наша цільова змінна - "rate"**

# %% [markdown]
# Вгадаємо параметри.

# %%
# Define a parameter grid
param_grid = {
    "n_epochs": [5, 10, 20],
    "n_factors": [50, 100, 200],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.4, 0.6],
}

# Define a GridSearchCV instance
gs = GridSearchCV(SVD, param_grid, measures=["rmse", "mae"], cv=5)

# Fit the grid search instance
gs.fit(data)

# Best RMSE score
print(gs.best_score["rmse"])

# Combination of parameters that gave the best RMSE score
print(gs.best_params["rmse"])
# Out:
# 0.9567816528585036
# {'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}

# %% [markdown]
# Бачимо, що найкраща (найменша) середньоквадратична похибка для такої моделі дають параметри
#
# {'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}
#
#
# Переконаємося у цьому, явно подивившись результати **крос-валідацій**:

# %%
from itertools import product

# Define the parameters
n_epochs = [5, 10, 20]
n_factors = [50, 100, 200]
lr_all = [0.002, 0.005]
reg_all = [0.4, 0.6]

# Create a list of dictionaries, each containing a unique combination of parameters
param_grid = [dict(zip(['n_epochs', 'n_factors', 'lr_all', 'reg_all'], values)) for values in product(n_epochs, n_factors, lr_all, reg_all)]

# Iterate over all parameters
for params in param_grid:
    algo = SVD(**params)

    # Perform cross validation
    results = cross_validate(algo, data, measures=["rmse", "mae"], cv=5, verbose=True)

    # Print RMSE and MAE scores
    print(f"Parameters {params}\nRMSE: ", results['test_rmse'].mean())
    print("MAE: ", results["test_mae"].mean())
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9864  0.9908  0.9946  0.9879  0.9923  0.9904  0.0029
# MAE (testset)     0.7958  0.8001  0.8020  0.7959  0.8010  0.7990  0.0026
# Fit time          0.17    0.16    0.16    0.16    0.16    0.16    0.00
# Test time         0.20    0.11    0.11    0.20    0.11    0.15    0.04
# Parameters {'n_epochs': 5, 'n_factors': 50, 'lr_all': 0.002, 'reg_all': 0.4}
# RMSE:  0.9903860456649156
# MAE:  0.7989576659310178
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9955  0.9984  0.9975  0.9940  1.0009  0.9973  0.0024
# MAE (testset)     0.8082  0.8087  0.8099  0.8062  0.8097  0.8085  0.0013
# Fit time          0.14    0.16    0.15    0.16    0.16    0.15    0.01
# Test time         0.11    0.20    0.11    0.11    0.19    0.14    0.04
# Parameters {'n_epochs': 5, 'n_factors': 50, 'lr_all': 0.002, 'reg_all': 0.6}
# RMSE:  0.9972646603252727
# MAE:  0.8085371415174999
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9650  0.9638  0.9769  0.9706  0.9733  0.9699  0.0049
# MAE (testset)     0.7770  0.7723  0.7828  0.7773  0.7830  0.7785  0.0040
# Fit time          0.14    0.17    0.19    0.17    0.15    0.16    0.02
# Test time         0.12    0.20    0.11    0.11    0.20    0.15    0.04
# Parameters {'n_epochs': 5, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}
# RMSE:  0.
'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}
# RMSE:  0.9556055389869924
# MAE:  0.7652664014848375
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9665  0.9681  0.9636  0.9766  0.9633  0.9676  0.0048
# MAE (testset)     0.7774  0.7790  0.7764  0.7857  0.7758  0.7789  0.0036
# Fit time          0.53    0.53    0.52    0.51    0.56    0.53    0.02
# Test time         0.11    0.11    0.20    0.11    0.11    0.13    0.03
# Parameters {'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.6}
# RMSE:  0.9676076133139446
# MAE:  0.7788591934986135
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9605  0.9642  0.9596  0.9630  0.9671  0.9629  0.0027
# MAE (testset)     0.7696  0.7747  0.7679  0.7732  0.7736  0.7718  0.0026
# Fit time          0.71    0.80    0.83    0.83    0.84    0.80    0.05
# Test time         0.20    0.13    0.12    0.23    0.12    0.16    0.04
# Parameters {'n_epochs': 20, 'n_factors': 100, 'lr_all': 0.002, 'reg_all': 0.4}
# RMSE:  0.9628918772325484
# MAE:  0.7718139505557527
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9767  0.9641  0.9749  0.9766  0.9723  0.9729  0.0047
# MAE (testset)     0.7866  0.7763  0.7861  0.7865  0.7834  0.7838  0.0039
# Fit time          0.82    0.82    0.84    0.86    0.86    0.84    0.02
# Test time         0.13    0.22    0.12    0.13    0.20    0.16    0.04
# Parameters {'n_epochs': 20, 'n_factors': 100, 'lr_all': 0.002, 'reg_all': 0.6}
# RMSE:  0.9729143933836515
# MAE:  0.7837999110850041
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9516  0.9527  0.9595  0.9606  0.9567  0.9562  0.0036
# MAE (testset)     0.7599  0.7630  0.7696  0.7715  0.7661  0.7660  0.0042
# Fit time          0.72    0.71    0.71    0.74    0.71    0.72    0.01
# Test time         0.12    0.20    0.11    0.11    0.20    0.15    0.04
# Parameters {'n_epochs': 20, 'n_factors': 100, 'lr_all': 0.005, 'reg_all': 0.4}
# RMSE:  0.9562227523654723
# MAE:  0.766012970687647
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9682  0.9697  0.9639  0.9684  0.9689  0.9678  0.0020
# MAE (testset)     0.7786  0.7812  0.7763  0.7784  0.7814  0.7792  0.0019
# Fit time          0.69    0.72    0.71    0.72    0.77    0.72    0.03
# Test time         0.11    0.11    0.20    0.11    0.11    0.13    0.04
# Parameters {'n_epochs': 20, 'n_factors': 100, 'lr_all': 0.005, 'reg_all': 0.6}
# RMSE:  0.9678060792287763
# MAE:  0.7791775190604396
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9629  0.9609  0.9642  0.9651  0.9602  0.9627  0.0019
# MAE (testset)     0.7721  0.7694  0.7723  0.7740  0.7706  0.7717  0.0016
# Fit time          1.04    1.05    1.03    1.06    1.07    1.05    0.01
# Test time         0.23    0.11    0.12    0.20    0.11    0.15    0.05
# Parameters {'n_epochs': 20, 'n_factors': 200, 'lr_all': 0.002, 'reg_all': 0.4}
# RMSE:  0.9626688876764552
# MAE:  0.7716769512420247
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9833  0.9660  0.9710  0.9754  0.9695  0.9730  0.0060
# MAE (testset)     0.7947  0.7766  0.7821  0.7856  0.7809  0.7840  0.0061
# Fit time          1.05    1.07    1.07    1.12    1.06    1.08    0.02
# Test time         0.21    0.13    0.11    0.20    0.12    0.15    0.04
# Parameters {'n_epochs': 20, 'n_factors': 200, 'lr_all': 0.002, 'reg_all': 0.6}
# RMSE:  0.9730229646085841
# MAE:  0.78395637383689
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9659  0.9462  0.9655  0.9432  0.9622  0.9566  0.0099
# MAE (testset)     0.7715  0.7584  0.7723  0.7544  0.7736  0.7660  0.0080
# Fit time          1.08    1.04    1.06    1.05    1.10    1.07    0.02
# Test time         0.12    0.20    0.11    0.11    0.20    0.15    0.04
# Parameters {'n_epochs': 20, 'n_factors': 200, 'lr_all': 0.005, 'reg_all': 0.4}
# RMSE:  0.9566112461165268
# MAE:  0.7660277390221177
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9628  0.9626  0.9703  0.9694  0.9747  0.9679  0.0047
# MAE (testset)     0.7760  0.7753  0.7802  0.7807  0.7852  0.7795  0.0036
# Fit time          1.05    1.04    1.06    1.05    1.06    1.05    0.01
# Test time         0.12    0.11    0.20    0.11    0.12    0.13    0.03
# Parameters {'n_epochs': 20, 'n_factors': 200, 'lr_all': 0.005, 'reg_all': 0.6}
# RMSE:  0.9679492721634911
# MAE:  0.7794868625538666

# %% [markdown]
# Дійсно, параметри
#
# {'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}
#
# дають найменші середньоквадратичну і середню похибки
#
# RMSE:  0.9556055389869924,
# MAE:  0.7652664014848375
#
# Це означає, що модель вгадує оцінку юзера для даного кіно з похибкою трохи мешою за 1 зірку з 5ти.
#
# Оскільки це порядка 20%, це величезна похибка і модель треба покращувати далі, або використовувати інші.

# %% [markdown]
# ### SVDpp

# %%
# Define a parameter grid
param_grid = {
    "n_epochs": [20],
    "n_factors": [50, 100],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.4, 0.6],
}

# Define a GridSearchCV instance
gs = GridSearchCV(SVDpp, param_grid, measures=["rmse", "mae"], cv=5)

# Fit the grid search instance
gs.fit(data)

# Best RMSE score
print(gs.best_score["rmse"])

# Combination of parameters that gave the best RMSE score
print(gs.best_params["rmse"])
# Out:
# 0.9564452137376623
# {'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}

# %% [markdown]
# Цей алгоритм більш ресурсо-затратний, і результат також гірший.

# %% [markdown]
# ### NMF

# %%
# Define a parameter grid
param_grid = {
    "n_epochs": [5, 10],
    "n_factors": [50, 100],
    "reg_pu": [0.4, 0.6],
    "reg_qi": [0.4, 0.6],
}
# Define a GridSearchCV instance
gs = GridSearchCV(NMF, param_grid, measures=["rmse", "mae"], cv=5)

# Fit the grid search instance
gs.fit(data)

# Best RMSE score
print(gs.best_score["rmse"])

# Combination of parameters that gave the best RMSE score
print(gs.best_params["rmse"])
# Out:
# 0.9646472845108172
# {'n_epochs': 10, 'n_factors': 100, 'reg_pu': 0.4, 'reg_qi': 0.4}

# %% [markdown]
# Ми отримали ще гірший результат.

# %% [markdown]
# ### Висновок
#
# Наразі найкращий результат на основі випадкових здогадок дала **SVD** з
#
# **{'n_epochs': 20, 'n_factors': 50, 'lr_all': 0.005, 'reg_all': 0.4}**
#
# і похибкою **~0.957**.
#
# Такий результат недостатній на мою думку, щоб використовувати таку модель в реальному житті.
#
# Можливо, кращу модель скоріше вийде підібрати варіюючи різні варіанти параметрів використовуючи SVD (у порівнянні з SVDpp та NFM), якщо починати з випадкових здогадок.
#
# Оскільки в моделі базових параметри чотири, то навіть в межах цих порядків, здогадка для яких була взята з документації surprise, навіть з кроком 0.1 процес знаходження найменшої середньоквадратичної похибки займе багато розрахунків і довгий час.
#
# Щоб пришвидшити процес, можливо потрібно більш свідомо підійти до вибору початкових здогадок, особливо для SVD++.
